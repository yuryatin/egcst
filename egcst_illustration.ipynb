# %%
from egcst import CrossSection

# %%
cs = CrossSection(input_file_name="input.txt", min_step=0.06)

# %%
cs.draw_blank()

# %%
cs.triangulate()
# Out:
# Process of triangulation:
# The polygon # 1 has been triangulated
# The polygon # 2 has been triangulated
# The polygon # 3 has been triangulated
# The polygon # 4 has been triangulated
# The polygon # 5 has been triangulated

# %%
cs.save_triangles()

# %%
cs.draw_triangles()
